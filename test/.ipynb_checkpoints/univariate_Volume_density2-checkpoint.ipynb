# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/univariate_MLE_density_data2.jl");

# %%
using Plots

r=1
p_exact(z)=0.5
scatter(Y[:,1], zeros(Float64,t),label ="sample")
plot!(p_exact, -r, r, label ="exact")

# %%
include("../src/ClassificationModels2.jl")
using .ClassificationModels2

d=5
R=1

eval_PDF=ClassificationModels2.model_volume(N,Y,t,R,d,ball_cons=true,bound=1e3);
# Out:
# number of attributes: 1
# sample size for traint set: 1000
# degree of polynomial estimation: 5
# radius of the ball centered at the origin containing the samples: 1
# maximal size of matrix variables: 6
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1036
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 4
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 1036
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 4
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 1036
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 1000              conic                  : 0
# Optimizer  - Semi-definite variables: 4                 scalarized             : 72
# Factor     - setup time             : 0.03              dense det. time        : 0.00
# Factor     - ML order time          : 0.02              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.37e+05          after factor           : 5.37e+05
# Factor     - dense dim.             : 0                 flops                  : 4.09e+08
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+03  1.0e+00  6.6e+00  0.00e+00   5.574603175e+00   0.000000000e+00   1.0e+00  0.04
# 1   5.4e+01  5.5e-02  1.5e+00  -9.97e-01  3.916268834e+01   5.052067124e+01   5.5e-02  0.11
# 2   6.4e-01  6.4e-04  8.1e-02  -9.37e-01  8.284013417e+02   1.201578632e+03   6.4e-04  0.17
# 3   2.4e-01  2.4e-04  5.9e-03  1.10e+00   6.184869781e+02   6.321591318e+02   2.4e-04  0.23
# 4   1.8e-01  1.8e-04  5.2e-04  5.58e+00   1.449367698e+02   1.450222001e+02   1.8e-04  0.30
# 5   1.3e-01  1.3e-04  2.7e-04  7.42e+00   1.624317401e+01   1.632937748e+01   1.3e-04  0.36
# 6   7.8e-03  7.9e-06  2.3e-06  1.84e+00   2.788627237e+00   2.789986821e+00   7.9e-06  0.43
# 7   9.1e-05  9.1e-08  2.5e-09  1.07e+00   2.009743218e+00   2.009753910e+00   9.1e-08  0.49
# 8   3.7e-11  3.0e-14  4.0e-19  1.00e+00   2.000000003e+00   2.000000003e+00   3.0e-14  0.56
# Optimizer terminated. Time: 0.56
#
# termination status :OPTIMAL
# integration :2.0000000031752885
# WARNING: replacing module ClassificationModels.

# %%
p_approx(z)=eval_PDF([z;zeros(N-1)])
plot!(p_approx, -r, r, label = "d = $(d)",#=legend=:bottomright,=#title = "t = $(t)")

# %%
#savefig(data*"/univariate_pdf_numsamp$(t).png")
# Out:
# "/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot/univariate_pdf_numsamp1000.png"
