# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/bivariate_data.jl");

# %%
d=2
# Out:
# 2

# %%
include("../src/ClassificationModels2.jl")
using .ClassificationModels2

R=1

eval_PDF1=ClassificationModels.model_volume(N,Y1,t,R,d,ball_cons=true);
# Out:
# number of attributes: 2
# sample size for traint set: 20
# degree of polynomial estimation: 2
# radius of the ball centered at the origin containing the samples: 1
# maximal size of matrix variables: 6
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
# ...

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx1(x1,x2)=eval_PDF1([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

contour(x1s, x2s, p_approx1,fill=true,title = "estimation 1")

scatter!(Y1[:,1], Y1[:,2],label ="sample 1",color="Blue")
scatter!(Y2[:,1], Y2[:,2],label ="sample 2",color="Red")

# %%
#savefig("/home/hoanganh/Desktop/math-topics/SOSModels/drafts/bivariate_classification_estimation1.png")
# Out:
# "/home/hoanganh/Desktop/math-topics/SOSModels/drafts/bivariate_classification_estimation1.png"

# %%
include("../src/ClassificationModels2.jl")
using .ClassificationModels2

eval_PDF2=ClassificationModels2.model_volume(N,Y2,t,R,d,ball_cons=true);
# Out:
# number of attributes: 2
# sample size for traint set: 20
# degree of polynomial estimation: 2
# radius of the ball centered at the origin containing the samples: 1
# maximal size of matrix variables: 6
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 20
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 2
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
# ...

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx2(x1,x2)=eval_PDF2([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

contour(x1s, x2s, p_approx2,fill=true,title = "estimation 2")

scatter!(Y1[:,1], Y1[:,2],label ="sample 1",color="Blue")
scatter!(Y2[:,1], Y2[:,2],label ="sample 2",color="Red")

# %%
#savefig("/home/hoanganh/Desktop/math-topics/SOSModels/drafts/bivariate_classification_estimation2.png")
# Out:
# "/home/hoanganh/Desktop/math-topics/SOSModels/drafts/bivariate_classification_estimation2.png"
