# %%
data="/home/hoanganh/Desktop/math-topics/algebraic_statistics/codes/datasets/plot" # path of data
include(data*"/bivariate_data.jl");

# %%
include("../src/ClassificationModels2.jl")
using .ClassificationModels2

n=N

c=Inf

X=Vector{Matrix{Float64}}(undef,2)
X[1]=Y1
X[2]=Y2

t=[t;t]

k=2

eval_sep_pol=ClassificationModels2.model_SVM(n,X,t,c,k,lamb=0.01)
# Out:
# number of attributes: n=2
# sample sizes for traint sets: t=[20, 20]
# degree of separating polynomial: k=2
# perturbed parameter: c=Inf
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 48
#   Cones                  : 1
#   Scalar variables       : 55
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 48
#   Cones                  : 1
#   Scalar variables       : 55
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer  - threads                : 4
# Optimizer  - solved problem         : the dual
# Optimizer  - Constraints            : 6
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 48                conic                  : 8
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 21                after factor           : 21
# Factor     - dense dim.             : 0                 flops                  : 1.79e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+00  1.0e+00  2.4e+00  0.00e+00   1.707106781e+00   2.928932188e-01   1.0e+00  0.01
# 1   1.6e-01  1.6e-01  2.7e-01  -2.18e-01  1.795955035e+00   1.688016508e+00   1.6e-01  0.01
# 2   6.5e-02  6.5e-02  1.6e-02  2.70e+00   7.966366578e-01   7.049578323e-01   6.5e-02  0.01
# 3   2.0e-02  2.0e-02  3.2e-03  2.86e+00   4.203311931e-01   4.094540777e-01   2.0e-02  0.01
# 4   6.2e-03  6.2e-03  5.4e-04  1.23e+00   3.766759817e-01   3.735334938e-01   6.2e-03  0.01
# 5   1.4e-03  1.4e-03  5.4e-05  1.09e+00   3.633889569e-01   3.627043220e-01   1.4e-03  0.01
# 6   2.6e-04  2.6e-04  4.3e-06  1.03e+00   3.605620332e-01   3.604315342e-01   2.6e-04  0.01
# 7   4.3e-05  4.3e-05  2.8e-07  1.00e+00   3.599940775e-01   3.599722756e-01   4.3e-05  0.01
# 8   3.9e-06  3.9e-06  7.6e-09  1.00e+00   3.598964557e-01   3.598944591e-01   3.9e-06  0.01
# 9   7.2e-09  7.2e-09  6.0e-13  1.00e+00   3.598859264e-01   3.598859227e-01   7.2e-09  0.01
# Optimizer terminated. Time: 0.02
# (::Main.ClassificationModels2.var"#eval_sep_pol#285"{Int64, Vector{Float64}}) (generic function with 1 method)

# %%
using Plots

import Contour: contours, levels, level, lines, coordinates

p_approx(x1,x2)=eval_sep_pol([x1;x2])

x1s = -1:0.01:1
x2s = -1:0.01:1

#contour(x1s, x2s, p_approx,fill=true,aspect_ratio = 1)
contour(x1s, x2s, p_approx,fill=true)

scatter!(Y1[:,1], Y1[:,2],label ="sample 1",color="Blue")
scatter!(Y2[:,1], Y2[:,2],label ="sample 2",color="Red")

# %%
#savefig("/home/hoanganh/Desktop/math-topics/SOSModels/drafts/bivariate_classification_estimation_svm2.png")
